# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\raopo\Downloads\Cleaned Reactions.xlsx')
print(df.columns.values)
print(df.head)
# Out:
# ['Unnamed: 0' 'Content ID' 'Reaction Type' 'Datetime']
# <bound method NDFrame.head of        Unnamed: 0                            Content ID Reaction Type  \
# 0               2  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 1               3  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 2               4  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 3               5  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# 4               6  97522e57-d9ab-4bd6-97bf-c24d952602d2       peeking
# ...           ...                                   ...           ...
# 24567       25548  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 24568       25549  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 24569       25550  75d6b589-7fae-4a6d-b0d0-752845150e56    interested
# 24570       25551  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 24571       25552  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                  Datetime
# ...

# %%
df1 = pd.read_excel(r'C:\Users\raopo\Downloads\Cleaned ReactionTypes.xlsx')
print(df1.columns.values)
print(df1.head)
# Out:
# ['Unnamed: 0' 'Reaction Type' 'Sentiment' 'Score']
# <bound method NDFrame.head of     Unnamed: 0 Reaction Type Sentiment  Score
# 0            0         heart  positive     60
# 1            1          want  positive     70
# 2            2       disgust  negative      0
# 3            3          hate  negative      5
# 4            4    interested  positive     30
# 5            5   indifferent   neutral     20
# 6            6          love  positive     65
# 7            7    super love  positive     75
# 8            8       cherish  positive     70
# 9            9         adore  positive     72
# 10          10          like  positive     50
# 11          11       dislike  negative     10
# 12          12     intrigued  positive     45
# 13          13       peeking   neutral     35
# 14          14        scared  negative     15
# 15          15       worried  negative     12>

# %%
file = pd.merge(left= df, right=df1, how='inner', on='Reaction Type')
print(file.columns.values)
print(file)
# Out:
# ['Unnamed: 0_x' 'Content ID' 'Reaction Type' 'Datetime' 'Unnamed: 0_y'
#  'Sentiment' 'Score']
#        Unnamed: 0_x                            Content ID Reaction Type  \
# 0                 2  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 1                38  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2                40  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 3                47  9f737e0a-3cdd-4d29-9d24-753f4e3be810       dislike
# 4                75  230c4e4d-70c3-461d-b42c-ec09396efb3f       dislike
# ...             ...                                   ...           ...
# 24567         25489  435007a5-6261-4d8b-b0a4-55fdc189754b         adore
# 24568         25491  435007a5-6261-4d8b-b0a4-55fdc189754b         adore
# 24569         25512  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore
# 24570         25524  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore
# 24571         25531  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore
#
# ...

# %%
df3 = pd.read_excel(r'C:\Users\raopo\Downloads\Cleaned Content 1.xlsx')
print(df3.columns.values)
print(df3)
# Out:
# ['Unnamed: 0' 'Content ID' 'Content Type' 'Category']
#      Unnamed: 0                            Content ID Content Type  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6        photo
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180        video
# ..          ...                                   ...          ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb        video
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c          GIF
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b        audio
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7          GIF
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56        audio
#
#             Category
# 0           Studying
# 1     healthy eating
# 2     healthy eating
# ...

# %%
mergedFile = pd.merge(left=file, right=df3, how='inner', on = 'Content ID')
print(mergedFile.columns.values)
# Out:
# ['Unnamed: 0_x' 'Content ID' 'Reaction Type' 'Datetime' 'Unnamed: 0_y'
#  'Sentiment' 'Score' 'Unnamed: 0' 'Content Type' 'Category']

# %%
display(mergedFile)
# Out:
#        Unnamed: 0_x                            Content ID Reaction Type  \
# 0                 2  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 1                38  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2                40  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 3                 3  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 4                12  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# ...             ...                                   ...           ...
# 24567         17352  99fcc8a6-550f-47a1-b312-aba8a031f6c7         heart
# 24568         20400  004e820e-49c3-4ba2-9d02-62db0065410c         heart
# 24569         25200  a7849ef3-5930-4ba9-9cbe-e215811e713e         heart
# 24570          3968  e5f1a4c6-2b27-4c8b-ac9a-21bb6ef7c946          want
# 24571          1507  c59e27e9-0439-4699-8ea0-5e93f662a05d         adore
#
#                  Datetime  Unnamed: 0_y Sentiment  Score  Unnamed: 0  \
# ...

# %%
m = mergedFile.drop(['Unnamed: 0_x','Unnamed: 0_y','Unnamed: 0'], axis=1)
display(m)
# Out:
#                                  Content ID Reaction Type            Datetime  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike 2021-06-17 12:22:51
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike 2020-11-09 02:49:59
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike 2020-11-29 21:33:04
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared 2021-04-18 05:13:58
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared 2020-11-02 06:28:53
# ...                                     ...           ...                 ...
# 24567  99fcc8a6-550f-47a1-b312-aba8a031f6c7         heart 2021-02-26 15:33:26
# 24568  004e820e-49c3-4ba2-9d02-62db0065410c         heart 2021-03-09 08:50:44
# 24569  a7849ef3-5930-4ba9-9cbe-e215811e713e         heart 2020-09-26 22:01:17
# 24570  e5f1a4c6-2b27-4c8b-ac9a-21bb6ef7c946          want 2021-02-12 11:54:33
# 24571  c59e27e9-0439-4699-8ea0-5e93f662a05d         adore 2021-02-02 15:29:19
#
# ...

# %%
#saving dataset

file_name = 'mergedData.csv'
m.to_csv(file_name, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\raopo\Documents\Portfolio\accenture\accentue.ipynb Cell 9 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/raopo/Documents/Portfolio/accenture/accentue.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> #saving dataset
#       <a href='vscode-notebook-cell:/c%3A/Users/raopo/Documents/Portfolio/accenture/accentue.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> file_name = 'mergedData.csv'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/raopo/Documents/Portfolio/accenture/accentue.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> m.to_csv(file_name, index=False)
#
# NameError: name 'm' is not defined

# %%
df = pd.read_csv(r'C:\Users\raopo\Documents\Portfolio\accenture\mergedData.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24572 entries, 0 to 24571
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Content ID     24572 non-null  object
#  1   Reaction Type  24572 non-null  object
#  2   Datetime       24572 non-null  object
#  3   Sentiment      24572 non-null  object
#  4   Score          24572 non-null  int64
#  5   Content Type   24572 non-null  object
#  6   Category       24572 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.3+ MB
